# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../raw_data/all_data_info.csv')
print(df.shape)
df.head()
# Out:
# (103250, 12)
#            artist    date     genre  pixelsx  pixelsy  size_bytes   source  \
# 0  Barnett Newman  1955.0  abstract  15530.0   6911.0   9201912.0  wikiart
# 1  Barnett Newman  1950.0  abstract  14559.0   6866.0   8867532.0  wikiart
# 2     kiri nichol  2013.0       NaN   9003.0   9004.0   1756681.0      NaN
# 3     kiri nichol  2013.0       NaN   9003.0   9004.0   1942046.0      NaN
# 4     kiri nichol  2013.0       NaN   9003.0   9004.0   1526212.0      NaN
#
#                   style                  title artist_group  in_train  \
# 0  Color Field Painting                  Uriel   train_only      True
# 1  Color Field Painting  Vir Heroicus Sublimis   train_only      True
# 2         Neoplasticism                    NaN    test_only     False
# 3         Neoplasticism                    NaN    test_only     False
# 4         Neoplasticism                    NaN    test_only     False
#
#   new_filename
# 0   102257.jpg
# 1    75232.jpg
# 2    32145.jpg
# ...

# %%
# Out:
# 0                  Barnett Newman
# 1                  Barnett Newman
# 2                     kiri nichol
# 3                     kiri nichol
# 4                     kiri nichol
#                    ...
# 103245            Jackson Pollock
# 103246           Bernardo Strozzi
# 103247                 Josef Sima
# 103248             Brett Whiteley
# 103249    Amadeo de Souza-Cardoso
# Name: artist2, Length: 103250, dtype: object

# %%
df['url']='https://www.wikiart.org/fr/'+df['artist']+'/'+df['title']+'-'+df['date']

# %%
df.head()
# Out:
#            artist    date     genre  pixelsx  pixelsy  size_bytes   source  \
# 0  Barnett Newman  1955.0  abstract  15530.0   6911.0   9201912.0  wikiart
# 1  Barnett Newman  1950.0  abstract  14559.0   6866.0   8867532.0  wikiart
# 2     kiri nichol  2013.0       NaN   9003.0   9004.0   1756681.0      NaN
# 3     kiri nichol  2013.0       NaN   9003.0   9004.0   1942046.0      NaN
# 4     kiri nichol  2013.0       NaN   9003.0   9004.0   1526212.0      NaN
#
#                   style                  title artist_group  in_train  \
# 0  Color Field Painting                  Uriel   train_only      True
# 1  Color Field Painting  Vir Heroicus Sublimis   train_only      True
# 2         Neoplasticism                    NaN    test_only     False
# 3         Neoplasticism                    NaN    test_only     False
# 4         Neoplasticism                    NaN    test_only     False
#
#   new_filename                                        url
# ...

# %%
def get_infos_by_filename(df, name):
    return df.query(f"new_filename == '{name}' ")

# %%
infos = get_infos_by_filename(df, '102257.jpg')
infos
# Out:
#            artist    date     genre  pixelsx  pixelsy  size_bytes   source  \
# 0  Barnett Newman  1955.0  abstract  15530.0   6911.0   9201912.0  wikiart
#
#                   style  title artist_group  in_train new_filename
# 0  Color Field Painting  Uriel   train_only      True   102257.jpg
